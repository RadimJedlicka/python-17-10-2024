# %% [markdown]
# <h6 align=right> 🐍 Python akademie - lekce 12 - 16.01.2024</h6>
#
# ---

# %% [markdown]
# <br>
#
# # <h1 align=center><font size=24><b> 12_02: Webscraping</font></h1>
#
# <br>

# %% [markdown]
# <br>
#
# ---
#
# ### **Zajímavé odkazy z této lekce:**
#
# * [Oficiální dokumentace pro balíček **requests** (requests.readthedocs.io)](https://requests.readthedocs.io/en/master/)
# * [Oficiální dokumentace pro balíček **beautifulsoup** (crummy.com)](https://www.crummy.com/software/BeautifulSoup/)
#
# ---
#
# <br>

# %% [markdown]
# <br>
#
# ## **Průzkum webu**
#
# ---

# %% [markdown]
# Nejprve si společně odpovězme na otázku, pokud byste byli vy majitelé webu, chtěli byste, aby **ostatní uživatele mohli volně pracovat s vašimi daty**?
#
# <br>
#
# Na takovou otázku je někdy jednoduché odpovědět, jindy ne. Pokud chcete vědět, jestli web umožňuje uživatelům poskytnout konkrétní data. Jednoduše doplňte za konkrétní adresu `robots.txt`.
# ```bash
# https://www.idnes.cz/robots.txt
# https://www.airbnb.ca/robots.txt
# ```
#
# <br>
#
# Tento dokument v podstatě oznamuje všem crawlerům, botům, scraperům, co mohou nebo nemohou procházet-indexovat.

# %% [markdown]
# <br>
#
# ## **Náš cíl**
#
# ---

# %% [markdown]
# Pojďme se společně podívat na webovou stránku [Heroes3](https://heroes3.cz/hraci/index.php?page=1&order=&razeni=DESC).
#
# <br>
#
# Pomocí Pythonu se budeme snažit získat (*scrapovat*) tabulku hráčů. Tedy všechna jména v tabulce a k nim příslušné údaje (společně vybereme).
#
# <br>
#
# Postup vypadá většinou následovně:
# - Získání HTML souborů z konkrétního webu,
# - rozdělení dat, pro snadnější vyhledávání,
# - uložení dat,
# - možné celý proces zopakovat na další stránce, nebo ukončit.
#
# <br>

# %% [markdown]
# <br>
#
# ## **Jaká data máme k dispozici?**
#
# ---

# %% [markdown]
# Prvním krokem je vyšetřit, jakým způsobem jsou data, která chceme získat, uložená.
#
# <br>
#
# Proto v našem prohlížeči použijeme pravé tlačítko myši a vybereme možnost `zobrazit zdrojový kód stránky` (příp. *view source page*).
#
# <br>
#
# Na následném zdroji uvidíme něco podobného:
# ```html
# <!DOCTYPE html>
# <html lang ="cs">
#     <head> ... </head>
# ```
#
# Na úplně prvním řádku vidíme, jaký má zdroj formát. Jde o `html`.
#
# <br>

# %% [markdown]
# <br>
#
# ## **HTML**
#
# ---

# %% [markdown]
# Jde opět o typ textového souboru, který je zorganizovaný pomocí tzv. _tagů/elementů_ (proto ~markup), který nejčastěji tvoří strukturu webových stránek.
#
# ```html
# <!-- pouze vzorovy zapis -->
# <div id="menu">
#     <li>
#         <a href="http://XXXXXXX.cz" title="">Homepage</a>
#     </li>
#     <li>
#         ...
#     </li>
# </div>
# ```
#
# <br>

# %% [markdown]
# ### **Tagy**
#
# Tagy jsou nápadné svojí hierarchickou strukturou. Nicméně tuto strukturu často vůbec nevnímáme, protože se uchovaná někde na pozadí.
#
# <br>
#
# Prohlížeče nám často představují až vyrenderovanou grafickou podobu, kterou známe z každodenního používání/vyhledávání.
#
# <br>
#
# Všimněte si, že některé tagy jsou zarovnané a jiné odsazené.
#
# <br>
#
# Díky zarovnání můžeme vyšetřit strukturu hierarchie:
#
# - **rodičovský** tag `<div>`,
# - **potomek** tag `<li>`, `<a>`,
# - **sourozenec**, pokud je několiv potomků společně odsazených
#
# <br>
#
# ### **Atributy**
#
# Kromě toho, že tvoří samotnou strukturu html, můžou obsahovat doplňující atributy:
#
# ```html
# <div id="menu">
#     <a href="http://XXXXXXX.cz"></a>
# <div class="sloupec">
# ```
#
# <br>
#
# Pomocí těchto atributů můžeme jednotlivé tagy lépe najít. Dále mohou obsahovat různé odkazy, identifikátory, případně text, který hledáme.
#
# <br>
#
# Formát jaký dodržují je podobný slovníkům v Pythonu:
# ```html
# <div id="menu">  <!--id(klic)="menu"(hodnota)-->
# ```

# %% [markdown]
# <br>
#
# ## **Dotazování na server**
#
# ---

# %% [markdown]
# Abychom mohli s údaji, které jsou k dispozici na webu, pracovat, je potřeba získat konkretní `html` soubor.
#
# <br>
#
# Tento proces za nás obyčejně obstarává prohlížeč, protože vzdálený server o příslušné `html` (`css` + `js` soubory) požádá.
#
# <br>
#
# ## **Python odesílá požadavky**
#
# ---
#
# Stejně jako náš prohlížeč, tak můžeme Python instruovat, aby pro nás provedl to stejné, co prohlížeč.
#
# <br>
#
# Tedy vytvořil požadavek na serveru a obratem získal odpověď obsahující data.
#
# <br>
#
# Pomocí knihovny `requests` (příp. i dalších jiných) můžeme posílat požadavky typu:
# 1. **post**
# 2. **get**
# 3. **put**
#
# <br>
#
# Který budete používat vy záleží na webu, se kterým pracujete. Opět si ukážeme přímo v prohlížeči.

# %% [markdown]
# <br>
#
# ## **Requests, funkce `get`**
#
# ---
# Nejprve však musíme na žádoucí stránce opět kliknout pravým tlačítkem myši a vybrat v prohlížeči `inspect element`.
#
#
# Následně se objeví na spodu stránky lišta, ve které najdeme v záhlaví možnost `network` (tady sledujeme jakou metodu prohlížeč používá při komunikaci se serverem):
#
# V rámci prohlížeče zkontrolujeme, o který typ požadavku jde nyní:

# %%
# pip install requests

# %%
import requests       # nejprve nutne nainstalovat balicek

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'JSONDecodeError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet_version',
#  'charset_normalizer_version',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
#  'patch',
#  'post',
#  'put',
#  'request',
#  'session',
#  'sessions',
#  'ssl',
#  'status_codes',
#  'structures',
#  'urllib3',
#  'utils',
#  'warnings']

# %%
help(requests.get)   # zobrazime si napovedu
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %% [markdown]
# ### Vstupní hodnoty:

# %%
url = "https://heroes3.cz/hraci/index.php?page=1&order=&razeni=DESC"
vystupni_soubor = "vystup_tab_1.csv"

# %% [markdown]
# ### Odeslání požadavku:

# %%
odp_serveru = requests.get(url)

# %%
type(odp_serveru)
# Out:
# requests.models.Response

# %%
odp_serveru.text
# Out:
# '<!DOCTYPE html>\n<html lang ="cs">\n<head>\n<meta charset="UTF-8" />\n<meta name="description" content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." />\n<meta name="keywords" content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" />\n<title>Liga Heroes 3 - Hráči</title>\n<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" crossorigin="anonymous"><link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/common.css" />\n<link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/menu.css" />\n<link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/footer.css" />\n<link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/ramecky.css" />\n<link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/nova_hra.css" />\n<link rel="shortcut icon" href="https://heroes3.cz/favicon.png"  type="image/x-icon" />\n</head>\n<body>\n<div id="div_logo"></div>\n<div id="div_main">\n<div id="div_menu"><ul>\r\n  <li><a href="https://heroes3.cz" title="">Domů</a></li>\r\n  <li class="active" ><a href="https://heroes3.cz/hraci" title="">Hráči</a></li>\r\n  <li><a href="https://heroes3.cz/hry" title="">Hry</a></li>\r\n  <li><a href="https://heroes3.cz/turnaje" title="">Turnaje</a></li>\r\n  <li><a href="https://heroes3.cz/diskuze" title="">Diskuze</a></li>\r\n  <li><a href="https://heroes3.cz/statistiky" title="">Statistiky</a></li>\t\t\t\r\n  <li><a href="https://heroes3.cz/galerie" title="">Galerie</a></li>\r\n  <li><a href="https://heroes3.cz/liga_info" title="">Liga Info</a></li>\r\n  <li><a href="https://heroes3.cz/jak_hrat_online" title="">Jak hrát online</a></li>\r\n  <li><a href="https://heroes3.cz/odkazy" title="">Odkazy</a></li>\t\t\t\r\n  </ul></div><div class="sloupec" style="width: 310px"><div class="ramecek">\n<div class="ramecek286_1">\n<h2>Přihlášení</h2>\n</div>\n<div class="ramecek_stred"><div class="ramecek286_2">\n<form action="/hraci/index.php?page=1&amp;order=&amp;razeni=DESC" method="post" enctype="multipart/form-data">\n<table class="nic">\n\r\n  <tr>\r\n   <td><i class="fas fa-user"></i></td>\r\n   <td>\n<input type="text" name="jmeno" size="15" maxlength="256" value="" class="textbox " />\n</td>\r\n   <td><button class="submit" style="width: 110px" type="submit" name="Prihlasit" value="Přihlásit" title="Přihlásit" >Přihlásit</button></td>\r\n  </tr>\r\n  <tr>\r\n   <td><i class="fas fa-key"></i></td>\r\n   <td>\n<input type="password" name="heslo" size="15" maxlength="59" value="" class="textbox " />\n</td>\r\n   <td>\n<input class="checkbox" type="checkbox" name="trvale" value="1" title="Označit" />\n trvalé přihlášení</td>\r\n  </tr>\r\n  <tr>\r\n   <td>&nbsp;</i></td>\r\n   <td align=\'center\'>&nbsp;&nbsp;<br><a href=\'https://heroes3.cz/registrace.php\' style=\'text-decoration: underline;\'>Založit nový účet </a></td>\r\n   <td>&nbsp;</td>\r\n  </tr> \r\n  </table>\n</form>\n</div></div>\n<div class="ramecek286_3">\n</div>\n</div>\n\r\n<div class="ramecek">\n<div class="ramecek286_1">\n<h2>Hledání uživatele</h2>\n</div>\n<div class="ramecek_stred"><div class="ramecek286_2">\n<form action="/hraci/index.php" method="post" enctype="multipart/form-data">\n<table class="nic">\n<tr class="even">\n<td><i class="fas fa-user"></i>&nbsp;</td>\n<td>\n<input type="text" name="hledat" size="15" maxlength="256" value="" class="textbox " />\n</td>\n<td><button class="submit" style="width: 110px" type="submit" name="submit_hledat" value="Vyhledat" title="Vyhledat" >Vyhledat</button></td>\n</tr>\n</table>\n</form>\n</div></div>\n<div class="ramecek286_3">\n</div>\n</div>\n</div><div class="sloupec"><div class="ramecek">\n<div class="ramecek1024_1">\n<h2>Tabulka hráčů</h2>\n</div>\n<div class="ramecek_stred"><div class="ramecek1024_2">\n<form action="/hraci/ ...

# %%
odp_serveru.text[1:16]
# Out:
# '!DOCTYPE html>\n'

# %% [markdown]
# #### Raw html
#
# Vidíme, že podoba, kterou nyní `html` získalo, neni moc užitečná. Protože s `html` budeme chtít podrobně pracovat a vyhledávat v něm, musíme vrácené údaje zpracovat (rozdělit~parsovat).<br />
#
# Toho dosáhneme opět použitím vhodné knihovny, která nám práci usnadní. Mrkněte na [pypi.org](https://pypi.org/).

# %% [markdown]
# <br>
#
# ## **Beautifulsoup**
#
# ---

# %% [markdown]
# Asi jeden z těch nejznámějších parserů určených k rozdělování `html`, `xml` atd. Opět musíme nejprve nainstalovat (jedná se o balíček třetí strany).
#
# <br>
#
# V našem virtuálním pracovním prostředí:
# ```bash
# $ pip3 install beautifulsoup
# $ pip3 freeze > requirements.txt
# ```

# %% [markdown]
# <br>
#
# ### **Vstupní hodnoty**

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_1 = "https://heroes3.cz/hraci/index.php?page=1&order=&razeni=DESC"
url_2 = "https://heroes3.cz/hraci/index.php?page=2&order=&razeni=DESC"

# %% [markdown]
# <br>
#
# ### **Odeslání požadavku:**

# %%
odp_serveru = requests.get(url_1)

# %%
print(odp_serveru)
# Out:
# <Response [200]>

# %%
type(odp_serveru.text)
# Out:
# str

# %%
print(odp_serveru.text)
# Out:
# <!DOCTYPE html>
# <html lang ="cs">
# <head>
# <meta charset="UTF-8" />
# <meta name="description" content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." />
# <meta name="keywords" content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" />
# <title>Liga Heroes 3 - Hráči</title>
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" crossorigin="anonymous"><link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/common.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/menu.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/footer.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/ramecky.css" />
# <link rel="Stylesheet" type="text/css" href="https://heroes3.cz/_include/css/nova_hra.css" />
# <link rel="shortcut icon" href="https://heroes3.cz/favicon.png"  type="image/x-icon" />
# </head>
# <body>
# <div id="div_logo"></div>
# <div id="div_main">
# <div id="div_menu"><ul>
#   <li><a href="https://heroes3.cz" title="">Domů</a></li>
#   <li class="active" ><a href="https://heroes3.cz/hraci" title="">Hráči</a></li>
#   <li><a href="https://heroes3.cz/hry" title="">Hry</a></li>
#   <li><a href="https://heroes3.cz/turnaje" title="">Turnaje</a></li>
#   <li><a href="https://heroes3.cz/diskuze" title="">Diskuze</a></li>
#   <li><a href="https://heroes3.cz/statistiky" title="">Statistiky</a></li>
#   <li><a href="https://heroes3.cz/galerie" title="">Galerie</a></li>
#   <li><a href="https://heroes3.cz/liga_info" title="">Liga Info</a></li>
#   <li><a href="https://heroes3.cz/jak_hrat_online" title="">Jak hrát online</a></li>
#   <li><a href="https://heroes3.cz/odkazy" title="">Odkazy</a></li>
#   </ul></div><div class="sloupec" style="width: 310px"><div class="ramecek">
# <div class="ramecek286_1">
# <h2>Přihlášení</h2>
# </div>
# <div class="ramecek_stred"><div class="ramecek286_2">
# <form action="/hraci/index.php?page=1&amp;order=&amp;razeni=DESC" method="post" enctype="multipart/form-data">
# <table class="nic">
#
#   <tr>
#    <td><i class="fas fa-user"></i></td>
#    <td>
# <input type="text" name="jmeno" size="15" maxlength="256" value="" class="textbox " />
# </td>
#    <td><button class="submit" style="width: 110px" type="submit" name="Prihlasit" value="Přihlásit" title="Přihlásit" >Přihlásit</button></td>
#   </tr>
#   <tr>
#    <td><i class="fas fa-key"></i></td>
#    <td>
# <input type="password" name="heslo" size="15" maxlength="59" value="" class="textbox " />
# </td>
#    <td>
# <input class="checkbox" type="checkbox" name="trvale" value="1" title="Označit" />
#  trvalé přihlášení</td>
#   </tr>
#   <tr>
#    <td>&nbsp;</i></td>
#    <td align='center'>&nbsp;&nbsp;<br><a href='https://heroes3.cz/registrace.php' style='text-decoration: underline;'>Založit nový účet </a></td>
#    <td>&nbsp;</td>
#   </tr>
#   </table>
# </form>
# </div></div>
# <div class="ramecek286_3">
# </div>
# </div>
#
# <div class="ramecek">
# <div class="ramecek286_1">
# <h2>Hledání uživatele</h2>
# </div>
# <div class="ramecek_stred"><div class="ramecek286_2">
# <form action="/hraci/index.php" method="post" enctype="multipart/form-data">
# <table class="nic">
# <tr class="even">
# <td><i class="fas fa-user"></i>&nbsp;</td>
# <td>
# <input type="text" name="hledat" size="15" maxlength="256" value="" class="textbox " />
# </td>
</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img src="https://heroes3.cz/_include/img/skupiny/5.png" alt="2. Liga" title="2. Liga" style="cursor: help;" /></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=5322">gabo</a></td>
# <td class="right">0</td>
# <td class="right">1952</td>
# <td class="right">107</td>
# <td class="right">232</td>
# <td class="right">46%</td>
# <td class="right">13. 6. 2017</td>
# <td class="right">167</td>
# <td class="right">137</td>
# </tr>
# <tr class="even">
# <td class="right">40.</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img src="https://heroes3.cz/_include/img/skupiny/5.png" alt="2. Liga" title="2. Liga" style="cursor: help;" /></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=2">Lord.Alex</a></td>
# <td class="right">0</td>
# <td class="right">1943</td>
# <td class="right">1464</td>
# <td class="right">3238</td>
# <td class="right">45%</td>
# <td class="right">5. 11. 2008</td>
# <td class="right">999</td>
# <td class="right">7812</td>
# </tr>
# </table>
# </form>
# <br><br><form action="/hraci/index.php" method="post" enctype="multipart/form-data">
# <table class="tab_top">
# <tr>
# <td><div style = "width: 75px">&nbsp;</div></td>
# <td><div style = "width: 75px">&nbsp;</div></td>
# <td><span class='podklad'> 1 / 94</span></td>
# <td><a href="/hraci/index.php?page=2&amp;order=&amp;razeni=DESC"class="button">další &gt;</a></td>
# <td><a href="/hraci/index.php?page=94&amp;order=&amp;razeni=DESC"class="button">poslední &gt;&gt;</a></td>
# </tr>
# </table>
# </form>
# </div></div>
# <div class="ramecek1024_3">
# </div>
# </div>
# </div>
# <hr style="clear: left" />
# <div id="div_footer">
# <table style="width: 300px; margin: auto"><tr class="even">
# <td><a href="http://validator.w3.org/check?uri=referer"><img src="https://heroes3.cz/_include/img/misc/html5-validated.png" alt="Valid HTML 5" title="Valid HTML 5"  /></a></td>
# <td><a href="http://jigsaw.w3.org/css-validator/check/referer"><img src="https://heroes3.cz/_include/img/misc/vcss.gif" alt="Valid CSS 3" title="Valid CSS 3"  /></a></td>
# <td>&nbsp;verze&nbsp;webu&nbsp;1.9</td>
# </tr>
# <table>
# </div>
# </div>
# </body>
# </html>

# %%
print(odp_serveru.text[:16])
# Out:
# <!DOCTYPE html>

# %% [markdown]
# <br>
#
# ### **Parsování html**

# %%
help(BeautifulSoup)

# %%
soup = BeautifulSoup(odp_serveru.text, 'html.parser')   # promenna + typ parseru
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="cs">
# <head>
# <meta charset="utf-8"/>
# <meta content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." name="description"/>
# <meta content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" name="keywords"/>
# <title>Liga Heroes 3 - Hráči</title>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/><link href="https://heroes3.cz/_include/css/common.css" rel="Stylesheet" type="text/css">
# <link href="https://heroes3.cz/_include/css/menu.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/_include/css/footer.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/_include/css/ramecky.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/_include/css/nova_hra.css" rel="Stylesheet" type="text/css"/>
# <link href="https://heroes3.cz/favicon.png" rel="shortcut icon" type="image/x-icon"/>
# </link></head>
# <body>
# <div id="div_logo"></div>
# <div id="div_main">
# <div id="div_menu"><ul>
# <li><a href="https://heroes3.cz" title="">Domů</a></li>
# <li class="active"><a href="https://heroes3.cz/hraci" title="">Hráči</a></li>
# <li><a href="https://heroes3.cz/hry" title="">Hry</a></li>
# <li><a href="https://heroes3.cz/turnaje" title="">Turnaje</a></li>
# <li><a href="https://heroes3.cz/diskuze" title="">Diskuze</a></li>
# <li><a href="https://heroes3.cz/statistiky" title="">Statistiky</a></li>
# <li><a href="https://heroes3.cz/galerie" title="">Galerie</a></li>
# <li><a href="https://heroes3.cz/liga_info" title="">Liga Info</a></li>
# <li><a href="https://heroes3.cz/jak_hrat_online" title="">Jak hrát online</a></li>
# <li><a href="https://heroes3.cz/odkazy" title="">Odkazy</a></li>
# </ul></div><div class="sloupec" style="width: 310px"><div class="ramecek">
# <div class="ramecek286_1">
# <h2>Přihlášení</h2>
# </div>
# <div class="ramecek_stred"><div class="ramecek286_2">
# <form action="/hraci/index.php?page=1&amp;order=&amp;razeni=DESC" enctype="multipart/form-data" method="post">
# <table class="nic">
# <tr>
# <td><i class="fas fa-user"></i></td>
# <td>
# <input class="textbox" maxlength="256" name="jmeno" size="15" type="text" value=""/>
# </td>
# <td><button class="submit" name="Prihlasit" style="width: 110px" title="Přihlásit" type="submit" value="Přihlásit">Přihlásit</button></td>
# </tr>
# <tr>
# <td><i class="fas fa-key"></i></td>
# <td>
# <input class="textbox" maxlength="59" name="heslo" size="15" type="password" value=""/>
# </td>
# <td>
# <input class="checkbox" name="trvale" title="Označit" type="checkbox" value="1"/>
#  trvalé přihlášení</td>
# </tr>
# <tr>
# <td> </td>
# <td align="center">  <br/><a href="https://heroes3.cz/registrace.php" style="text-decoration: underline;">Založit nový účet </a></td>
# <td> </td>
# </tr>
# </table>
# </form>
# </div></div>
# <div class="ramecek286_3">
# </div>
# </div>
# <div class="ramecek">
# <div class="ramecek286_1">
# <h2>Hledání uživatele</h2>
# </div>
# <div class="ramecek_stred"><div class="ramecek286_2">
# <form action="/hraci/index.php" enctype="multipart/form-data" method="post">
# <table class="nic">
# <tr class="even">
# <td><i class="fas fa-user"></i> </td>
# <td>
# <input class="textbox" maxlength="256" name="hledat" size="15" type="text" value=""/>
# </td>
# <td><button class="submit" name="submit_hledat" style="width: 110px" title="Vyhledat" type="submit" value="Vyhledat">Vyhledat</button></td>
# </tr>
# </table>
# </form>
# </div></div>
# <div class="ramecek286_3">
# </div>
# </div>
# </div><div class="sloupec"><div class="ramecek">
# <div class="ramecek1024_1">
# <h2>Tabulka hráčů</h2>
# </div>
# <div class="ramecek_stred"><div class="ramecek1024_2">
# <form action="/hraci/index.php" enctype="multipart/form-data" method="post">
# <table class="tab_top">
# <tr>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">POŘADÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">SKUPINA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">JMÉNO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">BODY</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">ELO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order
# </tr>
# </table>
# </form>
# </div></div>
# <div class="ramecek1024_3">
# </div>
# </div>
# </div>
# <hr style="clear: left"/>
# <div id="div_footer">
# <table style="width: 300px; margin: auto"><tr class="even">
# <td><a href="http://validator.w3.org/check?uri=referer"><img alt="Valid HTML 5" src="https://heroes3.cz/_include/img/misc/html5-validated.png" title="Valid HTML 5"/></a></td>
# <td><a href="http://jigsaw.w3.org/css-validator/check/referer"><img alt="Valid CSS 3" src="https://heroes3.cz/_include/img/misc/vcss.gif" title="Valid CSS 3"/></a></td>
# <td> verze webu 1.9</td>
# </tr>
# <table>
# </table></table></div>
# </div>
# </body>
# </html>

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_decode_markup',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
isinstance(soup, BeautifulSoup)
# Out:
# True

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="cs">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Liga a turnaje v počítačové hře Heroes of Might and Magic III." name="description"/>
#   <meta content="Heroes of Might and Magic 3, Heroes 3, liga, turnaje, online, hra, HoMaM, HMM, Hamachi, GameRanger" name="keywords"/>
#   <title>
#    Liga Heroes 3 - Hráči
#   </title>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.10/css/all.css" integrity="sha384-+d0P83n9kaQMCwj8F4RJB66tzIwOKmrdb46+porD/OvrJ+37WqIM7UoBtwHO6Nlg" rel="stylesheet"/>
#   <link href="https://heroes3.cz/_include/css/common.css" rel="Stylesheet" type="text/css">
#    <link href="https://heroes3.cz/_include/css/menu.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/_include/css/footer.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/_include/css/ramecky.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/_include/css/nova_hra.css" rel="Stylesheet" type="text/css"/>
#    <link href="https://heroes3.cz/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   </link>
#  </head>
#  <body>
#   <div id="div_logo">
#   </div>
#   <div id="div_main">
#    <div id="div_menu">
#     <ul>
#      <li>
#       <a href="https://heroes3.cz" title="">
#        Domů
#       </a>
#      </li>
#      <li class="active">
#       <a href="https://heroes3.cz/hraci" title="">
#        Hráči
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/hry" title="">
#        Hry
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/turnaje" title="">
#        Turnaje
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/diskuze" title="">
#        Diskuze
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/statistiky" title="">
#        Statistiky
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/galerie" title="">
#        Galerie
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/liga_info" title="">
#        Liga Info
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/jak_hrat_online" title="">
#        Jak hrát online
#       </a>
#      </li>
#      <li>
#       <a href="https://heroes3.cz/odkazy" title="">
#        Odkazy
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="sloupec" style="width: 310px">
#     <div class="ramecek">
#      <div class="ramecek286_1">
#       <h2>
#        Přihlášení
#       </h2>
#      </div>
#      <div class="ramecek_stred">
#       <div class="ramecek286_2">
#        <form action="/hraci/index.php?page=1&amp;order=&amp;razeni=DESC" enctype="multipart/form-data" method="post">
#         <table class="nic">
#          <tr>
#           <td>
#            <i class="fas fa-user">
#            </i>
#           </td>
#           <td>
#            <input class="textbox" maxlength="256" name="jmeno" size="15" type="text" value=""/>
#           </td>
#           <td>
#            <button class="submit" name="Prihlasit" style="width: 110px" title="Přihlásit" type="submit" value="Přihlásit">
#             Přihlásit
#            </button>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            <i class="fas fa-key">
#            </i>
#           </td>
#           <td>
#            <input class="textbox" maxlength="59" name="heslo" size="15" type="password" value=""/>
#           </td>
#           <td>
#            <input class="checkbox" name="trvale" title="Označit" type="checkbox" value="1"/>
#            trvalé přihlášení
#           </td>
#          </tr>
#          <tr>
#           <td>
#           </td>
#           <td align="center">
#            <br/>
#            <a href="https://heroes3.cz/registrace.php" style="text-decoration: underline;">
#             Založit nový účet
#            </a>
#           </td>
#           <td>
#           </td>
#          </tr>
#         </table>
#        </form>
#       </div>
#      </div>
#      <div class="ramecek286_3">
#      </div>
#     </div>
#     <div class="ramecek">
#      <div class="ramecek286_1">
#       <h2>
#        Hledání uživatele
#       </h2>
#      </div>
#      <div class="ramecek_stred">
#       <div class="ramecek286_2">
#        <form action="/hraci/index.php" enctype="multipart/form-data" method="post">
#         <table class="nic">
#          <tr class="even">
#           <td>
#            <i class="fas fa-user">
#            </i>
#           </td>
#           <td>
#            <input class="textbox" maxlength="256" name="hledat" size="15" type="text" value=""/>
#           </td>
#           <td>
#            <button class="submit" name="submit_hledat" style="width: 110px" title="Vyhledat" type="submit" value="Vyhledat">
#             Vyhledat
#            </button>
#           </td>
#          </tr>
#         </table>
#        </form>
#       </div>
#      </div>
#      <div class="ramecek286_3">
#      </div>
#     </div>
#    </div>
#    <div class="sloupec">
#     <div class="ramecek">
#      <div class="ramecek1024_1">
#       <h2>
#        Tabulka hráčů
#       </h2>
#      </div>
#      <div class="ramecek_stred">
#       <div class="ramecek1024_2">
#        <form action="/hraci/index.php" enctype="multipart/form-data" method="post">
#         <table class="tab_top">
#          <tr>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#             POŘADÍ
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#             SKUPINA
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">
#             JMÉNO
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#             BODY
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">
#             ELO
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">
#             VÍTĚZSTVÍ
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">
#             CELKEM HER
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">
#             ÚSPĚŠNOST
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=registrace&amp;razeni=DESC">
#             REGISTRACE
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=karma&amp;razeni=DESC">
#             KARMA
#            </a>
#           </th>
#           <th>
#            <a href="/hraci/index.php?page=1&amp;order=prispevky&amp;razeni=DESC">
#             PŘÍSPĚVKY
#            </a>
#           </th>
#          </tr>
#          <tr>
#           <td class="right">
#            1.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3113">
#             Scooby
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2004
#           </td>
#           <td class="right">
#            303
#           </td>
#           <td class="right">
#            439
#           </td>
#           <td class="right">
#            69%
#           </td>
#           <td class="right">
#            29. 12. 2012
#           </td>
#           <td class="right">
#            122
#           </td>
#           <td class="right">
#            1280
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            2.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=823">
#             karcma
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2004
#           </td>
#           <td class="right">
#            242
#           </td>
#           <td class="right">
#            427
#           </td>
#           <td class="right">
#            57%
#           </td>
#           <td class="right">
#            17. 4. 2010
#           </td>
#           <td class="right">
#            145
#           </td>
#           <td class="right">
#            671
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            3.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5320">
#             siska96
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1939
#           </td>
#           <td class="right">
#            90
#           </td>
#           <td class="right">
#            159
#           </td>
#           <td class="right">
#            57%
#           </td>
#           <td class="right">
#            11. 6. 2017
#           </td>
#           <td class="right">
#            115
#           </td>
#           <td class="right">
#            168
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            4.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5131">
#             Pepix
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1896
#           </td>
#           <td class="right">
#            139
#           </td>
#           <td class="right">
#            244
#           </td>
#           <td class="right">
#            57%
#           </td>
#           <td class="right">
#            16. 2. 2016
#           </td>
#           <td class="right">
#            148
#           </td>
#           <td class="right">
#            647
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            5.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5321">
#             Lord Slayer
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1770
#           </td>
#           <td class="right">
#            149
#           </td>
#           <td class="right">
#            433
#           </td>
#           <td class="right">
#            34%
#           </td>
#           <td class="right">
#            11. 6. 2017
#           </td>
#           <td class="right">
#            225
#           </td>
#           <td class="right">
#            392
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            6.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=656">
#             SD
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2298
#           </td>
#           <td class="right">
#            514
#           </td>
#           <td class="right">
#            737
#           </td>
#           <td class="right">
#            70%
#           </td>
#           <td class="right">
#            2. 1. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            963
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            7.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=28">
#             KekelZpekel
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2257
#           </td>
#           <td class="right">
#            308
#           </td>
#           <td class="right">
#            404
#           </td>
#           <td class="right">
#            76%
#           </td>
#           <td class="right">
#            10. 11. 2008
#           </td>
#           <td class="right">
#            3
#           </td>
#           <td class="right">
#            1669
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            8.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=958">
#             Unreal
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2194
#           </td>
#           <td class="right">
#            295
#           </td>
#           <td class="right">
#            381
#           </td>
#           <td class="right">
#            77%
#           </td>
#           <td class="right">
#            7. 7. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            460
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            9.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=294">
#             DavidHakl
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2180
#           </td>
#           <td class="right">
#            161
#           </td>
#           <td class="right">
#            273
#           </td>
#           <td class="right">
#            59%
#           </td>
#           <td class="right">
#            11. 6. 2009
#           </td>
#           <td class="right">
#            18
#           </td>
#           <td class="right">
#            533
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            10.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5307">
#             naoblaku
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1661
#           </td>
#           <td class="right">
#            127
#           </td>
#           <td class="right">
#            317
#           </td>
#           <td class="right">
#            40%
#           </td>
#           <td class="right">
#            24. 4. 2017
#           </td>
#           <td class="right">
#            201
#           </td>
#           <td class="right">
#            627
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            11.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3">
#             Kacer
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2203
#           </td>
#           <td class="right">
#            146
#           </td>
#           <td class="right">
#            229
#           </td>
#           <td class="right">
#            64%
#           </td>
#           <td class="right">
#            5. 11. 2008
#           </td>
#           <td class="right">
#            73
#           </td>
#           <td class="right">
#            353
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            12.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=222">
#             H34D
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2188
#           </td>
#           <td class="right">
#            413
#           </td>
#           <td class="right">
#            563
#           </td>
#           <td class="right">
#            73%
#           </td>
#           <td class="right">
#            8. 5. 2009
#           </td>
#           <td class="right">
#            305
#           </td>
#           <td class="right">
#            1343
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            13.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1017">
#             Maras
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2150
#           </td>
#           <td class="right">
#            347
#           </td>
#           <td class="right">
#            471
#           </td>
#           <td class="right">
#            74%
#           </td>
#           <td class="right">
#            14. 8. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            866
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            14.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=800">
#             ChuckNorris
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2139
#           </td>
#           <td class="right">
#            430
#           </td>
#           <td class="right">
#            674
#           </td>
#           <td class="right">
#            64%
#           </td>
#           <td class="right">
#            2. 4. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1984
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            15.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1">
#             Tomis
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2087
#           </td>
#           <td class="right">
#            72
#           </td>
#           <td class="right">
#            97
#           </td>
#           <td class="right">
#            74%
#           </td>
#           <td class="right">
#            5. 11. 2008
#           </td>
#           <td class="right">
#            7
#           </td>
#           <td class="right">
#            1368
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            16.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3165">
#             Bruce_Lee
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2082
#           </td>
#           <td class="right">
#            25
#           </td>
#           <td class="right">
#            40
#           </td>
#           <td class="right">
#            63%
#           </td>
#           <td class="right">
#            1. 2. 2013
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            78
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            17.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=30">
#             Afroman
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2074
#           </td>
#           <td class="right">
#            153
#           </td>
#           <td class="right">
#            199
#           </td>
#           <td class="right">
#            77%
#           </td>
#           <td class="right">
#            12. 11. 2008
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            810
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            18.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1533">
#             chichtofnuk
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2069
#           </td>
#           <td class="right">
#            372
#           </td>
#           <td class="right">
#            540
#           </td>
#           <td class="right">
#            69%
#           </td>
#           <td class="right">
#            26. 1. 2011
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1344
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            19.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1122">
#             Vítek
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2062
#           </td>
#           <td class="right">
#            138
#           </td>
#           <td class="right">
#            183
#           </td>
#           <td class="right">
#            75%
#           </td>
#           <td class="right">
#            25. 9. 2010
#           </td>
#           <td class="right">
#            4
#           </td>
#           <td class="right">
#            423
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            20.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=727">
#             PetoPalo
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2055
#           </td>
#           <td class="right">
#            132
#           </td>
#           <td class="right">
#            215
#           </td>
#           <td class="right">
#            61%
#           </td>
#           <td class="right">
#            21. 2. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            472
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            21.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=7">
#             Tornádo
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2020
#           </td>
#           <td class="right">
#            120
#           </td>
#           <td class="right">
#            138
#           </td>
#           <td class="right">
#            87%
#           </td>
#           <td class="right">
#            6. 11. 2008
#           </td>
#           <td class="right">
#            12
#           </td>
#           <td class="right">
#            438
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            22.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=706">
#             acid
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2020
#           </td>
#           <td class="right">
#            172
#           </td>
#           <td class="right">
#            245
#           </td>
#           <td class="right">
#            70%
#           </td>
#           <td class="right">
#            10. 2. 2010
#           </td>
#           <td class="right">
#            36
#           </td>
#           <td class="right">
#            437
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            23.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1837">
#             Elfus
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2019
#           </td>
#           <td class="right">
#            83
#           </td>
#           <td class="right">
#            120
#           </td>
#           <td class="right">
#            69%
#           </td>
#           <td class="right">
#            4. 6. 2011
#           </td>
#           <td class="right">
#            1
#           </td>
#           <td class="right">
#            215
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            24.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=4290">
#             Friza
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2019
#           </td>
#           <td class="right">
#            12
#           </td>
#           <td class="right">
#            24
#           </td>
#           <td class="right">
#            50%
#           </td>
#           <td class="right">
#            4. 9. 2014
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            46
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            25.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5361">
#             BeerWarrior
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2018
#           </td>
#           <td class="right">
#            40
#           </td>
#           <td class="right">
#            58
#           </td>
#           <td class="right">
#            69%
#           </td>
#           <td class="right">
#            21. 10. 2017
#           </td>
#           <td class="right">
#            44
#           </td>
#           <td class="right">
#            28
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            26.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3331">
#             Michal Hruša
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2015
#           </td>
#           <td class="right">
#            205
#           </td>
#           <td class="right">
#            336
#           </td>
#           <td class="right">
#            61%
#           </td>
#           <td class="right">
#            4. 5. 2013
#           </td>
#           <td class="right">
#            -2
#           </td>
#           <td class="right">
#            519
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            27.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=2472">
#             Juan Manzana
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2001
#           </td>
#           <td class="right">
#            63
#           </td>
#           <td class="right">
#            128
#           </td>
#           <td class="right">
#            49%
#           </td>
#           <td class="right">
#            13. 3. 2012
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            227
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            28.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5271">
#             bonca
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1990
#           </td>
#           <td class="right">
#            80
#           </td>
#           <td class="right">
#            147
#           </td>
#           <td class="right">
#            54%
#           </td>
#           <td class="right">
#            8. 1. 2017
#           </td>
#           <td class="right">
#            92
#           </td>
#           <td class="right">
#            63
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            29.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=836">
#             Imposieble
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1986
#           </td>
#           <td class="right">
#            383
#           </td>
#           <td class="right">
#            599
#           </td>
#           <td class="right">
#            64%
#           </td>
#           <td class="right">
#            29. 4. 2010
#           </td>
#           <td class="right">
#            71
#           </td>
#           <td class="right">
#            2354
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            30.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=4493">
#             Pany
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1975
#           </td>
#           <td class="right">
#            9
#           </td>
#           <td class="right">
#            18
#           </td>
#           <td class="right">
#            50%
#           </td>
#           <td class="right">
#            5. 12. 2014
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            19
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            31.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=310">
#             Gigiman
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1978
#           </td>
#           <td class="right">
#            126
#           </td>
#           <td class="right">
#            186
#           </td>
#           <td class="right">
#            68%
#           </td>
#           <td class="right">
#            18. 6. 2009
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            281
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            32.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=4670">
#             Septienna
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1978
#           </td>
#           <td class="right">
#            9
#           </td>
#           <td class="right">
#            18
#           </td>
#           <td class="right">
#            50%
#           </td>
#           <td class="right">
#            17. 1. 2015
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            2
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            33.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=4073">
#             JCVD
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1969
#           </td>
#           <td class="right">
#            1
#           </td>
#           <td class="right">
#            6
#           </td>
#           <td class="right">
#            17%
#           </td>
#           <td class="right">
#            6. 6. 2014
#           </td>
#           <td class="right">
#            -3
#           </td>
#           <td class="right">
#            11
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            34.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=2104">
#             Amroth_CZ
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1968
#           </td>
#           <td class="right">
#            58
#           </td>
#           <td class="right">
#            80
#           </td>
#           <td class="right">
#            73%
#           </td>
#           <td class="right">
#            30. 9. 2011
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            91
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            35.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3133">
#             PoloShock
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1968
#           </td>
#           <td class="right">
#            21
#           </td>
#           <td class="right">
#            36
#           </td>
#           <td class="right">
#            58%
#           </td>
#           <td class="right">
#            3. 1. 2013
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            49
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            36.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=3125">
#             Heibgd
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1966
#           </td>
#           <td class="right">
#            9
#           </td>
#           <td class="right">
#            16
#           </td>
#           <td class="right">
#            56%
#           </td>
#           <td class="right">
#            31. 12. 2012
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            23
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            37.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=4121">
#             ToxxicCloud
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1961
#           </td>
#           <td class="right">
#            4
#           </td>
#           <td class="right">
#            7
#           </td>
#           <td class="right">
#            57%
#           </td>
#           <td class="right">
#            5. 7. 2014
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            10
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            38.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=1025">
#             lyk
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1954
#           </td>
#           <td class="right">
#            60
#           </td>
#           <td class="right">
#            87
#           </td>
#           <td class="right">
#            69%
#           </td>
#           <td class="right">
#            19. 8. 2010
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            202
#           </td>
#          </tr>
#          <tr>
#           <td class="right">
#            39.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=5322">
#             gabo
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1952
#           </td>
#           <td class="right">
#            107
#           </td>
#           <td class="right">
#            232
#           </td>
#           <td class="right">
#            46%
#           </td>
#           <td class="right">
#            13. 6. 2017
#           </td>
#           <td class="right">
#            167
#           </td>
#           <td class="right">
#            137
#           </td>
#          </tr>
#          <tr class="even">
#           <td class="right">
#            40.
#           </td>
#           <td class="right">
#            <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#             <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#            </div>
#           </td>
#           <td>
#            <a href="https://heroes3.cz/hraci/detail.php?id=2">
#             Lord.Alex
#            </a>
#           </td>
#           <td class="right">
#            0
#           </td>
#           <td class="right">
#            1943
#           </td>
#           <td class="right">
#            1464
#           </td>
#           <td class="right">
#            3238
#           </td>
#           <td class="right">
#            45%
#           </td>
#           <td class="right">
#            5. 11. 2008
#           </td>
#           <td class="right">
#            999
#           </td>
#           <td class="right">
#            7812
#           </td>
#          </tr>
#         </table>
#        </form>
#        <br/>
#        <br/>
#        <form action="/hraci/index.php" enctype="multipart/form-data" method="post">
#         <table class="tab_top">
#          <tr>
#           <td>
#            <div style="width: 75px">
#            </div>
#           </td>
#           <td>
#            <div style="width: 75px">
#            </div>
#           </td>
#           <td>
#            <span class="podklad">
#             1 / 94
#            </span>
#           </td>
#           <td>
#            <a class="button" href="/hraci/index.php?page=2&amp;order=&amp;razeni=DESC">
#             další &gt;
#            </a>
#           </td>
#           <td>
#            <a class="button" href="/hraci/index.php?page=94&amp;order=&amp;razeni=DESC">
#             poslední &gt;&gt;
#            </a>
#           </td>
#          </tr>
#         </table>
#        </form>
#       </div>
#      </div>
#      <div class="ramecek1024_3">
#      </div>
#     </div>
#    </div>
#    <hr style="clear: left"/>
#    <div id="div_footer">
#     <table style="width: 300px; margin: auto">
#      <tr class="even">
#       <td>
#        <a href="http://validator.w3.org/check?uri=referer">
#         <img alt="Valid HTML 5" src="https://heroes3.cz/_include/img/misc/html5-validated.png" title="Valid HTML 5"/>
#        </a>
#       </td>
#       <td>
#        <a href="http://jigsaw.w3.org/css-validator/check/referer">
#         <img alt="Valid CSS 3" src="https://heroes3.cz/_include/img/misc/vcss.gif" title="Valid CSS 3"/>
#        </a>
#       </td>
#       <td>
#        verze webu 1.9
#       </td>
#      </tr>
#      <table>
#      </table>
#     </table>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# <br>
#
# ### **Rozdělené html podle tagů**

# %% [markdown]
# Nyní máme sice `html` soubor rozdělený, ale potřebujeme vybrat jen ta data, která nás zajímají. Tedy vybrat z tabulky hráčů tyto sloupečky:
# 1. pořadí
# 2. jméno
# 3. body
# 4. celkem her
# 5. vítězství
# 6. úspěšnost
#
# <br>
#
# Abychom správně dohledali obsah těchto tagů, budeme je muset najít ve struktuře zdrojového kódu, v prohlížeči (režim `inspect`).

# %% [markdown]
# <br>
#
# ### **Hledání rodičovského tagu**

# %% [markdown]
# Jakmile najdeme rodičovský tag, můžeme jej ověřit u jednotlivých údajů (`CSS path`):
# ```html
# form > table.tab_top > tbody > tr > td
# ```
#
# <br>
#
# Protože nás zajímají všichni hráči v tabulce, použijeme celý element `table`. Jakmile jej najdeme, můžeme si dále ověřit jestli nemá nějaký atribut, který by nám jej pomohl selektovat:
# ```html
# <table class="tab_top">
#     ...
# </table>
# ```

# %% [markdown]
# <br>
#
# ### **Tagy potomků**

# %% [markdown]
# Postupně procházíme všechny dědičné tagy a odpovíme společně na tyto otázky:
# 1. Co představuje tag: `<td></td>`?
# 2. Co představuje tag: `<tr></tr>`?
# 3. Co představuje tag: `<tbody></tbody>`?
# 4. Co představuje tag: `<table></table>`?

# %% [markdown]
# <br>
#
# ### **Selekce vhodných elementů**

# %% [markdown]
# Nejprve potřebujeme získat takový element, který obsahuje celou tabulku se všemi hráči. Projdeme tedy dostupné metody a zkusíme nějakou vybrat:

# %%
dir(BeautifulSoup)

# %%
help(BeautifulSoup.select)

# %%
help(BeautifulSoup.find)

# %%
help(BeautifulSoup.find_all)

# %% [markdown]
# <br>
#
# ### **Selekce tabulky s atributem `tab_top`**

# %%
table_tag_top = soup.find("table", {"class": "tab_top"})

# %%
print(table_tag_top.prettify())
# Out:
# <table class="tab_top">
#  <tr>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     POŘADÍ
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     SKUPINA
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">
#     JMÉNO
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">
#     BODY
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">
#     ELO
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">
#     VÍTĚZSTVÍ
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">
#     CELKEM HER
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">
#     ÚSPĚŠNOST
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=registrace&amp;razeni=DESC">
#     REGISTRACE
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=karma&amp;razeni=DESC">
#     KARMA
#    </a>
#   </th>
#   <th>
#    <a href="/hraci/index.php?page=1&amp;order=prispevky&amp;razeni=DESC">
#     PŘÍSPĚVKY
#    </a>
#   </th>
#  </tr>
#  <tr>
#   <td class="right">
#    1.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3113">
#     Scooby
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2004
#   </td>
#   <td class="right">
#    303
#   </td>
#   <td class="right">
#    439
#   </td>
#   <td class="right">
#    69%
#   </td>
#   <td class="right">
#    29. 12. 2012
#   </td>
#   <td class="right">
#    122
#   </td>
#   <td class="right">
#    1280
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    2.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=823">
#     karcma
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2004
#   </td>
#   <td class="right">
#    242
#   </td>
#   <td class="right">
#    427
#   </td>
#   <td class="right">
#    57%
#   </td>
#   <td class="right">
#    17. 4. 2010
#   </td>
#   <td class="right">
#    145
#   </td>
#   <td class="right">
#    671
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    3.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5320">
#     siska96
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1939
#   </td>
#   <td class="right">
#    90
#   </td>
#   <td class="right">
#    159
#   </td>
#   <td class="right">
#    57%
#   </td>
#   <td class="right">
#    11. 6. 2017
#   </td>
#   <td class="right">
#    115
#   </td>
#   <td class="right">
#    168
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    4.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5131">
#     Pepix
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1896
#   </td>
#   <td class="right">
#    139
#   </td>
#   <td class="right">
#    244
#   </td>
#   <td class="right">
#    57%
#   </td>
#   <td class="right">
#    16. 2. 2016
#   </td>
#   <td class="right">
#    148
#   </td>
#   <td class="right">
#    647
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    5.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Elitní 4" src="https://heroes3.cz/_include/img/skupiny/2.png" style="cursor: help;" title="Elitní 4"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5321">
#     Lord Slayer
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1770
#   </td>
#   <td class="right">
#    149
#   </td>
#   <td class="right">
#    433
#   </td>
#   <td class="right">
#    34%
#   </td>
#   <td class="right">
#    11. 6. 2017
#   </td>
#   <td class="right">
#    225
#   </td>
#   <td class="right">
#    392
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    6.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=656">
#     SD
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2298
#   </td>
#   <td class="right">
#    514
#   </td>
#   <td class="right">
#    737
#   </td>
#   <td class="right">
#    70%
#   </td>
#   <td class="right">
#    2. 1. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    963
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    7.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=28">
#     KekelZpekel
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2257
#   </td>
#   <td class="right">
#    308
#   </td>
#   <td class="right">
#    404
#   </td>
#   <td class="right">
#    76%
#   </td>
#   <td class="right">
#    10. 11. 2008
#   </td>
#   <td class="right">
#    3
#   </td>
#   <td class="right">
#    1669
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    8.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=958">
#     Unreal
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2194
#   </td>
#   <td class="right">
#    295
#   </td>
#   <td class="right">
#    381
#   </td>
#   <td class="right">
#    77%
#   </td>
#   <td class="right">
#    7. 7. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    460
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    9.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=294">
#     DavidHakl
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2180
#   </td>
#   <td class="right">
#    161
#   </td>
#   <td class="right">
#    273
#   </td>
#   <td class="right">
#    59%
#   </td>
#   <td class="right">
#    11. 6. 2009
#   </td>
#   <td class="right">
#    18
#   </td>
#   <td class="right">
#    533
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    10.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="Top 10" src="https://heroes3.cz/_include/img/skupiny/3.png" style="cursor: help;" title="Top 10"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5307">
#     naoblaku
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1661
#   </td>
#   <td class="right">
#    127
#   </td>
#   <td class="right">
#    317
#   </td>
#   <td class="right">
#    40%
#   </td>
#   <td class="right">
#    24. 4. 2017
#   </td>
#   <td class="right">
#    201
#   </td>
#   <td class="right">
#    627
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    11.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3">
#     Kacer
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2203
#   </td>
#   <td class="right">
#    146
#   </td>
#   <td class="right">
#    229
#   </td>
#   <td class="right">
#    64%
#   </td>
#   <td class="right">
#    5. 11. 2008
#   </td>
#   <td class="right">
#    73
#   </td>
#   <td class="right">
#    353
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    12.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=222">
#     H34D
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2188
#   </td>
#   <td class="right">
#    413
#   </td>
#   <td class="right">
#    563
#   </td>
#   <td class="right">
#    73%
#   </td>
#   <td class="right">
#    8. 5. 2009
#   </td>
#   <td class="right">
#    305
#   </td>
#   <td class="right">
#    1343
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    13.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1017">
#     Maras
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2150
#   </td>
#   <td class="right">
#    347
#   </td>
#   <td class="right">
#    471
#   </td>
#   <td class="right">
#    74%
#   </td>
#   <td class="right">
#    14. 8. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    866
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    14.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=800">
#     ChuckNorris
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2139
#   </td>
#   <td class="right">
#    430
#   </td>
#   <td class="right">
#    674
#   </td>
#   <td class="right">
#    64%
#   </td>
#   <td class="right">
#    2. 4. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1984
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    15.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1">
#     Tomis
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2087
#   </td>
#   <td class="right">
#    72
#   </td>
#   <td class="right">
#    97
#   </td>
#   <td class="right">
#    74%
#   </td>
#   <td class="right">
#    5. 11. 2008
#   </td>
#   <td class="right">
#    7
#   </td>
#   <td class="right">
#    1368
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    16.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3165">
#     Bruce_Lee
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2082
#   </td>
#   <td class="right">
#    25
#   </td>
#   <td class="right">
#    40
#   </td>
#   <td class="right">
#    63%
#   </td>
#   <td class="right">
#    1. 2. 2013
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    78
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    17.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=30">
#     Afroman
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2074
#   </td>
#   <td class="right">
#    153
#   </td>
#   <td class="right">
#    199
#   </td>
#   <td class="right">
#    77%
#   </td>
#   <td class="right">
#    12. 11. 2008
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    810
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    18.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1533">
#     chichtofnuk
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2069
#   </td>
#   <td class="right">
#    372
#   </td>
#   <td class="right">
#    540
#   </td>
#   <td class="right">
#    69%
#   </td>
#   <td class="right">
#    26. 1. 2011
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1344
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    19.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1122">
#     Vítek
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2062
#   </td>
#   <td class="right">
#    138
#   </td>
#   <td class="right">
#    183
#   </td>
#   <td class="right">
#    75%
#   </td>
#   <td class="right">
#    25. 9. 2010
#   </td>
#   <td class="right">
#    4
#   </td>
#   <td class="right">
#    423
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    20.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=727">
#     PetoPalo
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2055
#   </td>
#   <td class="right">
#    132
#   </td>
#   <td class="right">
#    215
#   </td>
#   <td class="right">
#    61%
#   </td>
#   <td class="right">
#    21. 2. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    472
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    21.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=7">
#     Tornádo
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2020
#   </td>
#   <td class="right">
#    120
#   </td>
#   <td class="right">
#    138
#   </td>
#   <td class="right">
#    87%
#   </td>
#   <td class="right">
#    6. 11. 2008
#   </td>
#   <td class="right">
#    12
#   </td>
#   <td class="right">
#    438
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    22.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=706">
#     acid
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2020
#   </td>
#   <td class="right">
#    172
#   </td>
#   <td class="right">
#    245
#   </td>
#   <td class="right">
#    70%
#   </td>
#   <td class="right">
#    10. 2. 2010
#   </td>
#   <td class="right">
#    36
#   </td>
#   <td class="right">
#    437
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    23.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1837">
#     Elfus
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2019
#   </td>
#   <td class="right">
#    83
#   </td>
#   <td class="right">
#    120
#   </td>
#   <td class="right">
#    69%
#   </td>
#   <td class="right">
#    4. 6. 2011
#   </td>
#   <td class="right">
#    1
#   </td>
#   <td class="right">
#    215
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    24.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=4290">
#     Friza
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2019
#   </td>
#   <td class="right">
#    12
#   </td>
#   <td class="right">
#    24
#   </td>
#   <td class="right">
#    50%
#   </td>
#   <td class="right">
#    4. 9. 2014
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    46
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    25.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5361">
#     BeerWarrior
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2018
#   </td>
#   <td class="right">
#    40
#   </td>
#   <td class="right">
#    58
#   </td>
#   <td class="right">
#    69%
#   </td>
#   <td class="right">
#    21. 10. 2017
#   </td>
#   <td class="right">
#    44
#   </td>
#   <td class="right">
#    28
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    26.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3331">
#     Michal Hruša
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2015
#   </td>
#   <td class="right">
#    205
#   </td>
#   <td class="right">
#    336
#   </td>
#   <td class="right">
#    61%
#   </td>
#   <td class="right">
#    4. 5. 2013
#   </td>
#   <td class="right">
#    -2
#   </td>
#   <td class="right">
#    519
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    27.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=2472">
#     Juan Manzana
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2001
#   </td>
#   <td class="right">
#    63
#   </td>
#   <td class="right">
#    128
#   </td>
#   <td class="right">
#    49%
#   </td>
#   <td class="right">
#    13. 3. 2012
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    227
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    28.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5271">
#     bonca
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1990
#   </td>
#   <td class="right">
#    80
#   </td>
#   <td class="right">
#    147
#   </td>
#   <td class="right">
#    54%
#   </td>
#   <td class="right">
#    8. 1. 2017
#   </td>
#   <td class="right">
#    92
#   </td>
#   <td class="right">
#    63
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    29.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=836">
#     Imposieble
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1986
#   </td>
#   <td class="right">
#    383
#   </td>
#   <td class="right">
#    599
#   </td>
#   <td class="right">
#    64%
#   </td>
#   <td class="right">
#    29. 4. 2010
#   </td>
#   <td class="right">
#    71
#   </td>
#   <td class="right">
#    2354
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    30.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="1. Liga" src="https://heroes3.cz/_include/img/skupiny/4.png" style="cursor: help;" title="1. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=4493">
#     Pany
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1975
#   </td>
#   <td class="right">
#    9
#   </td>
#   <td class="right">
#    18
#   </td>
#   <td class="right">
#    50%
#   </td>
#   <td class="right">
#    5. 12. 2014
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    19
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    31.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=310">
#     Gigiman
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1978
#   </td>
#   <td class="right">
#    126
#   </td>
#   <td class="right">
#    186
#   </td>
#   <td class="right">
#    68%
#   </td>
#   <td class="right">
#    18. 6. 2009
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    281
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    32.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=4670">
#     Septienna
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1978
#   </td>
#   <td class="right">
#    9
#   </td>
#   <td class="right">
#    18
#   </td>
#   <td class="right">
#    50%
#   </td>
#   <td class="right">
#    17. 1. 2015
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    2
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    33.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=4073">
#     JCVD
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1969
#   </td>
#   <td class="right">
#    1
#   </td>
#   <td class="right">
#    6
#   </td>
#   <td class="right">
#    17%
#   </td>
#   <td class="right">
#    6. 6. 2014
#   </td>
#   <td class="right">
#    -3
#   </td>
#   <td class="right">
#    11
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    34.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=2104">
#     Amroth_CZ
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1968
#   </td>
#   <td class="right">
#    58
#   </td>
#   <td class="right">
#    80
#   </td>
#   <td class="right">
#    73%
#   </td>
#   <td class="right">
#    30. 9. 2011
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    91
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    35.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3133">
#     PoloShock
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1968
#   </td>
#   <td class="right">
#    21
#   </td>
#   <td class="right">
#    36
#   </td>
#   <td class="right">
#    58%
#   </td>
#   <td class="right">
#    3. 1. 2013
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    49
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    36.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=3125">
#     Heibgd
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1966
#   </td>
#   <td class="right">
#    9
#   </td>
#   <td class="right">
#    16
#   </td>
#   <td class="right">
#    56%
#   </td>
#   <td class="right">
#    31. 12. 2012
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    23
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    37.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=4121">
#     ToxxicCloud
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1961
#   </td>
#   <td class="right">
#    4
#   </td>
#   <td class="right">
#    7
#   </td>
#   <td class="right">
#    57%
#   </td>
#   <td class="right">
#    5. 7. 2014
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    10
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    38.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=1025">
#     lyk
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1954
#   </td>
#   <td class="right">
#    60
#   </td>
#   <td class="right">
#    87
#   </td>
#   <td class="right">
#    69%
#   </td>
#   <td class="right">
#    19. 8. 2010
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    202
#   </td>
#  </tr>
#  <tr>
#   <td class="right">
#    39.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=5322">
#     gabo
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1952
#   </td>
#   <td class="right">
#    107
#   </td>
#   <td class="right">
#    232
#   </td>
#   <td class="right">
#    46%
#   </td>
#   <td class="right">
#    13. 6. 2017
#   </td>
#   <td class="right">
#    167
#   </td>
#   <td class="right">
#    137
#   </td>
#  </tr>
#  <tr class="even">
#   <td class="right">
#    40.
#   </td>
#   <td class="right">
#    <div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;">
#     <img alt="2. Liga" src="https://heroes3.cz/_include/img/skupiny/5.png" style="cursor: help;" title="2. Liga"/>
#    </div>
#   </td>
#   <td>
#    <a href="https://heroes3.cz/hraci/detail.php?id=2">
#     Lord.Alex
#    </a>
#   </td>
#   <td class="right">
#    0
#   </td>
#   <td class="right">
#    1943
#   </td>
#   <td class="right">
#    1464
#   </td>
#   <td class="right">
#    3238
#   </td>
#   <td class="right">
#    45%
#   </td>
#   <td class="right">
#    5. 11. 2008
#   </td>
#   <td class="right">
#    999
#   </td>
#   <td class="right">
#    7812
#   </td>
#  </tr>
# </table>

# %%
dir(table_tag_top)

# %% [markdown]
# Jakmile máme celou tabulku, snažíme se rozptyl zmenšit a najít pouze tagy s jednotlivými hráči. Vidíme, že každý hráč je na řádku. Dále, že každý řádek je schovaný za tagem `tr`.

# %% [markdown]
# <br>
#
# ### **Selekce elementů `tr`, řádků**

# %%
vsechny_tr = table_tag_top.find_all("tr")

# %%
dir(vsechny_tr)

# %%
print(vsechny_tr)
# Out:
# [<tr>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">POŘADÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">SKUPINA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=jmeno&amp;razeni=DESC">JMÉNO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=0&amp;razeni=DESC">BODY</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=elo&amp;razeni=DESC">ELO</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=vitezstvi&amp;razeni=DESC">VÍTĚZSTVÍ</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=celkem_her&amp;razeni=DESC">CELKEM HER</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=uspesnost&amp;razeni=DESC">ÚSPĚŠNOST</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=registrace&amp;razeni=DESC">REGISTRACE</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=karma&amp;razeni=DESC">KARMA</a></th>
# <th><a href="/hraci/index.php?page=1&amp;order=prispevky&amp;razeni=DESC">PŘÍSPĚVKY</a></th>
# </tr>, <tr>
# <td class="right">1.</td>
# <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/></div></td>
# <td><a href="https://heroes3.cz/hraci/detail.php?id=
# bs4.element.ResultSet

# %%
type(vsechny_tr[1])
# Out:
# bs4.element.Tag

# %% [markdown]
# Na začátku máme **záhlaví** (index `0`), bez toho se obejdeme, stačí aplikovat _slicování_, které datový typ `ResultSet` podporuje.
#
# <br>
#
# Nyní, když umíme rozdělit html na jednotlivé řádky (s jednotlivými hráči), potřebujeme konečně izolovat jednotlivé buňky, které obsahují konkrétní údaje.

# %% [markdown]
# <br>
#
# ### **Selekce jednotlivých buněk `td`**

# %%
for tr in vsechny_tr[1:]:             # vynechame zahlavi, budeme mit vlastni
    td_na_radku = tr.find_all("td")
    print(td_na_radku[0].get_text())  # Pozor, seznam bunek
    break                             # po prvnim cyklu ukoncime
# Out:
# 1.

# %%
from pprint import pprint
pprint(td_na_radku)
# Out:
# [<td class="right">1.</td>,
#  <td class="right"><div style="margin-top: -3px; margin-bottom: -3px; margin-right: 1px;"><img alt="Šampion" src="https://heroes3.cz/_include/img/skupiny/1.png" style="cursor: help;" title="Šampion"/></div></td>,
#  <td><a href="https://heroes3.cz/hraci/detail.php?id=3113">Scooby</a></td>,
#  <td class="right">0</td>,
#  <td class="right">2004</td>,
#  <td class="right">303</td>,
#  <td class="right">439</td>,
#  <td class="right">69%</td>,
#  <td class="right">29. 12. 2012</td>,
#  <td class="right">122</td>,
#  <td class="right">1280</td>]

# %%
print(td_na_radku[0].get_text())
# Out:
# 1.

# %%
print(td_na_radku[2].text)
# Out:
# Scooby

# %%
print(td_na_radku[2].string)
# Out:
# Scooby

# %%
print(type(td_na_radku[2].text))
print(type(td_na_radku[2].string))
print(type(td_na_radku[2].getText()))
# Out:
# <class 'str'>
# <class 'bs4.element.NavigableString'>
# <class 'str'>

# %%
print(td_na_radku[2].getText())
# Out:
# Scooby

# %%
def vyber_atributy_z_radku(tr_tag: "bs4.element.ResultSet"):
    """
    Z kazdeho radku (tr) vyber urcite bunky (td)[index])
    a zabal je do slovniku
    """
    return {
        "poradi": tr_tag[0].getText(),
        "jmeno": tr_tag[2].getText(),
        "vitezstvi": tr_tag[5].getText(),
        "celkem_her": tr_tag[6].getText()
    }

# %%
vysledky = []

for tr in vsechny_tr[1:]:
    td_na_radku = tr.find_all("td")
    data_hrace = vyber_atributy_z_radku(td_na_radku)
    vysledky.append(data_hrace)

# %%
from pprint import pprint
pprint(vysledky)
# Out:
# [{'celkem_her': '439', 'jmeno': 'Scooby', 'poradi': '1.', 'vitezstvi': '303'},
#  {'celkem_her': '427', 'jmeno': 'karcma', 'poradi': '2.', 'vitezstvi': '242'},
#  {'celkem_her': '159', 'jmeno': 'siska96', 'poradi': '3.', 'vitezstvi': '90'},
#  {'celkem_her': '244', 'jmeno': 'Pepix', 'poradi': '4.', 'vitezstvi': '139'},
#  {'celkem_her': '433',
#   'jmeno': 'Lord Slayer',
#   'poradi': '5.',
#   'vitezstvi': '149'},
#  {'celkem_her': '737', 'jmeno': 'SD', 'poradi': '6.', 'vitezstvi': '514'},
#  {'celkem_her': '404',
#   'jmeno': 'KekelZpekel',
#   'poradi': '7.',
#   'vitezstvi': '308'},
#  {'celkem_her': '381', 'jmeno': 'Unreal', 'poradi': '8.', 'vitezstvi': '295'},
#  {'celkem_her': '273',
#   'jmeno': 'DavidHakl',
#   'poradi': '9.',
#   'vitezstvi': '161'},
#  {'celkem_her': '317',
#   'jmeno': 'naoblaku',
#   'poradi': '10.',
#   'vitezstvi': '127'},
#  {'celkem_her': '229', 'jmeno': 'Kacer', 'poradi': '11.', 'vitezstvi': '146'},
#  {'celkem_her': '563', 'jmeno': 'H34D', 'poradi': '12.', 'vitezstvi': '413'},
#  {'celkem_her': '471', 'jmeno': 'Maras', 'poradi': '13.', 'vitezstvi': '347'},
#  {'celkem_her': '674',
#   'jmeno': 'ChuckNorris',
#   'poradi': '14.',
#   'vitezstvi': '430'},
#  {'celkem_her': '97', 'jmeno': 'Tomis', 'poradi': '15.', 'vitezstvi': '72'},
#  {'celkem_her': '40', 'jmeno': 'Bruce_Lee', 'poradi': '16.', 'vitezstvi': '25'},
#  {'celkem_her': '199', 'jmeno': 'Afroman', 'poradi': '17.', 'vitezstvi': '153'},
#  {'celkem_her': '540',
#   'jmeno': 'chichtofnuk',
#   'poradi': '18.',
#   'vitezstvi': '372'},
#  {'celkem_her': '183', 'jmeno': 'Vítek', 'poradi': '19.', 'vitezstvi': '138'},
#  {'celkem_her': '215',
#   'jmeno': 'PetoPalo',
#   'poradi': '20.',
#   'vitezstvi': '132'},
#  {'celkem_her': '138', 'jmeno': 'Tornádo', 'poradi': '21.', 'vitezstvi': '120'},
#  {'celkem_her': '245', 'jmeno': 'acid', 'poradi': '22.', 'vitezstvi': '172'},
#  {'celkem_her': '120', 'jmeno': 'Elfus', 'poradi': '23.', 'vitezstvi': '83'},
#  {'celkem_her': '24', 'jmeno': 'Friza', 'poradi': '24.', 'vitezstvi': '12'},
#  {'celkem_her': '58',
#   'jmeno': 'BeerWarrior',
#   'poradi': '25.',
#   'vitezstvi': '40'},
#  {'celkem_her': '336',
#   'jmeno': 'Michal Hruša',
#   'poradi': '26.',
#   'vitezstvi': '205'},
#  {'celkem_her': '128',
#   'jmeno': 'Juan Manzana',
#   'poradi': '27.',
#   'vitezstvi': '63'},
#  {'celkem_her': '147', 'jmeno': 'bonca', 'poradi': '28.', 'vitezstvi': '80'},
#  {'celkem_her': '599',
#   'jmeno': 'Imposieble',
#   'poradi': '29.',
#   'vitezstvi': '383'},
#  {'celkem_her': '18', 'jmeno': 'Pany', 'poradi': '30.', 'vitezstvi': '9'},
#  {'celkem_her': '186', 'jmeno': 'Gigiman', 'poradi': '31.', 'vitezstvi': '126'},
#  {'celkem_her': '18', 'jmeno': 'Septienna', 'poradi': '32.', 'vitezstvi': '9'},
#  {'celkem_her': '6', 'jmeno': 'JCVD', 'poradi': '33.', 'vitezstvi': '1'},
#  {'celkem_her': '80', 'jmeno': 'Amroth_CZ', 'poradi': '34.', 'vitezstvi': '58'},
#  {'celkem_her': '36', 'jmeno': 'PoloShock', 'poradi': '35.', 'vitezstvi': '21'},
#  {'celkem_her': '16', 'jmeno': 'Heibgd', 'poradi': '36.', 'vitezstvi': '9'},
#  {'celkem_her': '7', 'jmeno': 'ToxxicCloud', 'poradi': '37.', 'vitezstvi': '4'},
#  {'celkem_her': '87', 'jmeno': 'lyk', 'poradi': '38.', 'vitezstvi': '60'},
#  {'celkem_her': '232', 'jmeno': 'gabo', 'poradi': '39.', 'vitezstvi': '107'},
#  {'celkem_her': '3238',
#   'jmeno': 'Lord.Alex',
#   'poradi': '40.',
#   'vitezstvi': '1464'}]

# %% [markdown]
# kratší zápis

# %%
data_o_hracich: list = list()

for tr in vsechny_tr[1:]:
    data_o_hracich.append(vyber_atributy_z_radku(tr.find_all("td")))

# %%
pprint(data_o_hracich)

# %% [markdown]
# <br>
#
# Nyní umíme sbírat jednotlivé položky u všech hráčů, takže můžeme aplikovat stejný postup na celý `ResultSet` s použitím *list comprehension*.

# %%
data_o_hracich = [
    vyber_atributy_z_radku(tr.find_all("td"))
    for tr in vsechny_tr[1:]
]

# %%
print(data_o_hracich)

# %% [markdown]
# <br>
#
# ### **Ukládání údajů do souboru**

# %% [markdown]
# Úplně nakonec chceme námi posbírané údaje uložit ve formátu `csv` do příslušného souboru:

# %%
import csv
import traceback

def zapis_data(data: list, jmeno_souboru: str) -> str:
    """
    Zkus zapsat udaje z par. 'data' do souboru formatu .csv.
    """
    try:
        csv_soubor = open(jmeno_souboru, mode="w", encoding="utf-8")
        sloupce = data[0].keys()
        
    except FileExistsError:
        return traceback.format_exc()
    except IndexError:
        return traceback.format_exc()
    else:
        zapis = csv.DictWriter(csv_soubor, fieldnames=sloupce)
        zapis.writeheader()
        zapis.writerows(data)
        return "Saved"
    finally:
        csv_soubor.close()

# %%
vysledek = zapis_data(data_o_hracich, f"samples/tabulka_1.csv")

# %%
print(vysledek)

# %% [markdown]
# <br>
#
# ### **Vyzkoušíme další tabulky**
#
# Pokud vám správně funguje varianta pro první tabulku, zkuste vkládat odkazy pro další tabulky, resp. tabulky další v pořadí.
#
# <br>
#
# Případně můžete zapsat tento proces pomocí programu v Pythonu, který lze spouštět s různými argumenty (první pro číslo tabulky, druhý pro jméno výstupu v `csv`).

# %%
jmeno_csv = sys.argv[2]  # vystup_tab_1.csv
cislo_tab = sys.argv[1]  # 1

# %%
cislo_tab = "2"
url = f"https://heroes3.cz/hraci/index.php?page={cislo_tab}&order=&razeni=DESC"

# %% [markdown]
# <br>
#
# ## **S velkou mocí příchází velká zodpovědnost**
#
# ---
#
# 1. Než se pustíme do scrapingu, zkontolujeme `robots.txt` (allow/disallow)
# 2. Zkontrolujeme, jestli služba nenabízí API (není třeba scrapovat, ale využít endpoint)
# 3. Nezatěžujeme server velkým množstvím dotazů v krátkém časovém horizontu (pád->blokování)
# 4. Nepoužívám cizí data ke komerčním účelům (_pravidla&podmínky_)
# 5. requests, bs4, urllib.requests, htmlparser, requests-html, scrapy, selenium, aj.
#
# ---
#
# <br>
